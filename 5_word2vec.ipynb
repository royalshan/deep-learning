# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
  data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3082, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
reverse_dictionary[55]
# Out:
# 'such'

# %% [markdown]
# Meaning of each variable: <br>
# data: Number representation of words (ordinal id) <br>
# count: word and its occurrence count <br>
# dictonary: word and its ordinal id <br>
# reverse_dictionary: ordinal id and word <br>

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  #collections.deque is a generalization of stacks and queues 
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

# num_skips: number of neighbours for each focus word
# skip_window: number of focus word to ignore
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.669178
# Nearest to s: involved, protested, pixels, gini, pimp, wexford, mash, sale,
# Nearest to they: dagmar, fickle, bilirubin, ccf, annapolis, tells, misspelled, roofed,
# Nearest to world: ale, munk, tisdall, sava, stately, alioth, racks, investments,
# Nearest to many: manet, absorbance, topalov, mammal, savoie, rube, categorization, fared,
# Nearest to his: ballet, henderson, telegraph, veterinarians, reload, citro, hydrates, valerie,
# Nearest to war: enclosed, slugging, offside, diazepam, he, beck, constructs, scripture,
# Nearest to was: rousseau, willem, hostels, zimbabwean, policies, stadium, handbooks, maribor,
# Nearest to will: pvc, opold, ocampo, benevento, occupies, pe, simple, mayo,
# Nearest to he: slugging, subduction, war, cobol, ernest, month, handicapped, sei,
# Nearest to two: electrophilic, outings, thumb, bankrupted, blackhawks, partit, isaias, gilbertese,
# Nearest to not: ssbn, nabataean, vj, biographies, borman, legislate, sideshow, prologue,
# Nearest to american: formation, absent, konstantin, daffodils, constellation, dioceses, clarify, dismal,
# Nearest to to: canberra, abruptly, dispense, primed, dilbert, adapa, tate, rtiges,
# Nearest to at: heschel, detriment, algae, edna, nihilism, endowed, misplaced, xaf,
# Nearest to been: motte, grue, heh, inertial, weimar, augustin, erudition, action,
# Nearest to in: accelerated, tardis, egerton, superiority, chargers, birthrate, blessing, mattingly,
# Average loss at step 2000: 4.365210
# Average loss at step 4000: 3.869791
# Average loss at step 6000: 3.784852
# Average loss at step 8000: 3.690347
# Average loss at step 10000: 3.615630
# Nearest to s: his, and, phillips, proletarian, culminating, disbelief, incorporating, iron,
# Nearest to they: he, dagmar, there, not, annapolis, pontiff, bernie, discogs,
# Nearest to world: ale, frisian, racks, flagging, soi, first, alioth, palembang,
# Nearest to many: some, these, various, oaxaca, losses, railroads, their, corrado,
# Nearest to his: their, s, her, its, the, ballet, skyview, sopwith,
# Nearest to war: slugging, enclosed, beck, merman, unpredictability, boycotted, mathcal, sentry,
# Nearest to was: is, had, has, by, were, are, prodigal, been,
# Nearest to will: pvc, aspen, boundaries, mira, occupies, would, mayo, opold,
# Nearest to he: it, she, they, who, there, handicapped, then, ecuador,
# Nearest to two: three, five, four, six, eight, nine, seven, zero,
# Nearest to not: they, also, it, nabataean, to, biographies, freely, shri,
# Nearest to american: formation, dioceses, juli, clarify, stonewall, exemplified, retirement, highwayman,
# Nearest to to: would, tick, mariano, not, desalination, caspase, abruptly, qwerty,
# Nearest to at: after, in, heschel, parl, of, bonhomme, during, syme,
# Nearest to been: had, was, condamine, heh, expensive, augustin, unpowered, thinkpad,
# Nearest to in: on, of, from, egerton, at, with, after, between,
# Average loss at step 12000: 3.604975
# Average loss at step 14000: 3.572942
# Average loss at step 16000: 3.404723
# Average loss at step 18000: 3.459772
# Average loss at step 20000: 3.545672
# Nearest to s: aerosols, blanton, width, ackerman, eoin, scriptwriter, concentrate, wave,
# Nearest to they: he, there, we, you, she, not, who, it,
# Nearest to world: flagging, ale, palembang, advisable, racks, frisian, campaigner, cleve,
# Nearest to many: some, several, these, other, all, various, their, appreciative,
# Nearest to his: their, her, its, the, disco, haq, hoshea, jin,
# Nearest to war: merman, beck, slugging, enclosed, syntactically, unpredictability, camp, ammanati,
# Nearest to was: is, were, had, has, are, became, butchers, be,
# Nearest to will: would, can, could, may, must, to, should, pvc,
# Nearest to he: it, she, they, who, there, then, brevity, never,
# Nearest to two: three, four, five, six, eight, one, seven, zero,
# Nearest to not: freely, they, usually, to, it, grading, you, also,
# Nearest to american: british, juli, italian, whipping, fleischmann, highwayman, english, donahue,
# Nearest to to: would, will, not, for, dispense, may, tick, caspase,
# Nearest to at: in, after, during, with, scholz, toward, hay, on,
# Nearest to been: be, had, were, become, was, by, unpowered, condamine,
# Nearest to in: at, on, from, for, and, during, with, under,
# Average loss at step 22000: 3.498465
# Average loss at step 24000: 3.491533
# Average loss at step 26000: 3.479741
# Average loss at step 28000: 3.480716
# Average loss at step 30000: 3.504090
# Nearest to s: his, battled, wrap, ackerman, aerosols, frontage, phillips, its,
# Nearest to they: there, he, we, you, it, these, not, who,
# Nearest to world: flagging, judgement, priestley, cleve, campaigner, ale, faroe, advisable,
# Nearest to many: some, several, these, various, other, all, howlin, most,
# Nearest to his: their, her, its, the, s, applicability, grotesque, enhances,
# Nearest to war: merman, beck, slugging, secularization, misunderstandings, ammanati, enclosed, camp,
# Nearest to was: is, had, has, were, became, when, been, herse,
# Nearest to will: would, can, could, may, must, should, might, pvc,
# Nearest to he: she, it, they, who, there, never, brevity, then,
# Nearest to two: three, four, one, five, seven, eight, six, nine,
# Nearest to not: it, they, grading, we, freely, this, still, veneration,
# Nearest to american: british, italian, english, german, juli, retrieval, stonewall, french,
# Nearest to to: would, can, dispense, camelcase, caspase, will, postures, may,
# Nearest to at: in, during, heschel, near, after, muharram, under, enol,
# Nearest to been: become, be, was, were, subscription, exons, kip, unpowered,
# Nearest to in: at, of, during, chromatids, under, on, since, between,
# Average loss at step 32000: 3.503343
# Average loss at step 34000: 3.495763
# Average loss at step 36000: 3.452093
# Average loss at step 38000: 3.302467
# Average loss at step 40000: 3.426283
# Nearest to s: catahoula, aerosols, and, her, frontage, pixels, nsync, his,
# Nearest to they: we, he, there, you, it, these, she, dagmar,
# Nearest to world: flagging, judgement, faroe, racks, cleve, spaniard, ale, snowball,
# Nearest to many: some, several, these, various, most, other, appreciative, howlin,
# Nearest to his: their, her, its, the, my, heme, thread, polarization,
# Nearest to war: slugging, beck, merman, wars, gloucester, glen, enclosed, tilted,
# Nearest to was: is, became, has, were, had, be, prodigal, been,
# Nearest to will: can, would, may, could, must, might, should, cannot,
# Nearest to he: she, it, they, there, who, then, never, brevity,
# Nearest to two: three, five, four, seven, six, eight, one, zero,
# Nearest to not: freely, strikes, grading, we, they, you, usually, admission,
# Nearest to american: british, italian, english, australian, french, german, japanese, hurting,
# Nearest to to: dispense, will, would, can, caspase, may, desalination, could,
# Nearest to at: on, during, heschel, near, after, muharram, in, cares,
# Nearest to been: be, become, were, had, was, subscription, being, exons,
# Nearest to in: of, at, containing, egerton, from, for, during, under,
# Average loss at step 42000: 3.435155
# Average loss at step 44000: 3.455911
# Average loss at step 46000: 3.449178
# Average loss at step 48000: 3.354985
# Average loss at step 50000: 3.387529
# Nearest to s: phillips, frontage, pixels, ackerman, his, rohrabacher, penitent, skyview,
# Nearest to they: he, there, we, you, she, it, ilp, these,
# Nearest to world: faroe, judgement, csa, cleve, flagging, batting, cim, snowball,
# Nearest to many: some, several, various, these, both, all, other, manifestation,
# Nearest to his: their, her, its, my, our, the, whose, applicability,
# Nearest to war: slugging, wars, merman, beck, poland, precolonial, glen, deprecated,
# Nearest to was: is, has, were, had, became, be, been, being,
# Nearest to will: would, can, could, may, must, should, might, does,
# Nearest to he: she, it, they, who, there, then, brevity, never,
# Nearest to two: three, one, four, six, seven, eight, five, nine,
# Nearest to not: freely, strikes, now, invited, they, still, never, usually,
# Nearest to american: british, australian, italian, english, eid, french, hurting, vara,
# Nearest to to: may, can, would, desalination, refrigerators, will, could, dispense,
# Nearest to at: during, near, bal, on, heschel, in, muharram, heydrich,
# Nearest to been: become, be, was, had, being, already, were, subscription,
# Nearest to in: during, from, on, of, chromatids, lcc, buridan, since,
# Average loss at step 52000: 3.434911
# Average loss at step 54000: 3.426845
# Average loss at step 56000: 3.436435
# Average loss at step 58000: 3.398888
# Average loss at step 60000: 3.389787
# Nearest to s: shielded, skyview, eoin, circulated, dunne, arcology, elisha, injections,
# Nearest to they: we, you, there, he, she, not, ilp, these,
# Nearest to world: faroe, cleve, cim, nation, csa, mesoamerican, perspective, flagging,
# Nearest to many: some, several, various, these, all, most, such, appreciative,
# Nearest to his: her, their, its, my, our, the, skyview, thread,
# Nearest to war: wars, slugging, poland, beck, precolonial, merman, semiconductor, deprecated,
# Nearest to was: is, had, became, were, has, been, be, although,
# Nearest to will: would, could, may, can, must, might, should, does,
# Nearest to he: she, it, they, there, who, soon, we, eventually,
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to not: freely, they, you, strikes, still, now, invited, we,
# Nearest to american: british, australian, english, german, italian, european, eid, hurting,
# Nearest to to: may, dispense, would, t, must, desalination, not, tate,
# Nearest to at: near, during, in, anechoic, after, veteran, mismatch, keyboardist,
# Nearest to been: become, be, was, being, were, already, had, subscription,
# Nearest to in: chromatids, within, during, buridan, lcc, on, at, of,
# Average loss at step 62000: 3.239927
# Average loss at step 64000: 3.253521
# Average loss at step 66000: 3.405331
# Average loss at step 68000: 3.399495
# Average loss at step 70000: 3.360578
# Nearest to s: ackerman, aerosols, isbn, circulated, costing, elisha, lowe, frontage,
# Nearest to they: we, he, there, you, it, she, ilp, these,
# Nearest to world: faroe, nation, country, judgement, flagging, cleve, csa, cold,
# Nearest to many: some, several, various, these, all, most, both, other,
# Nearest to his: her, their, its, our, my, him, the, your,
# Nearest to war: wars, slugging, merman, poland, beck, precolonial, semiconductor, ecliptic,
# Nearest to was: is, has, were, had, became, been, be, sudbury,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to he: she, it, they, there, who, we, then, never,
# Nearest to two: three, four, six, seven, five, one, eight, zero,
# Nearest to not: still, now, freely, never, generally, strikes, invited, only,
# Nearest to american: british, english, australian, italian, vara, arrhenius, maternal, elegans,
# Nearest to to: will, can, dispense, jiangxi, towards, cannot, would, must,
# Nearest to at: near, during, nightclubs, in, veteran, on, cryopreservation, mismatch,
# Nearest to been: become, be, was, already, were, being, had, subscription,
# Nearest to in: within, during, on, chromatids, throughout, for, through, including,
# Average loss at step 72000: 3.376405
# Average loss at step 74000: 3.349811
# Average loss at step 76000: 3.320832
# Average loss at step 78000: 3.358746
# Average loss at step 80000: 3.373635
# Nearest to s: frontage, cracker, rohrabacher, circulated, isbn, qutb, imitative, wildstorm,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to world: cim, faroe, csa, nation, schemata, flagging, judgement, cleve,
# Nearest to many: some, several, various, these, most, all, numerous, both,
# Nearest to his: her, their, its, my, our, your, the, enhances,
# Nearest to war: wars, precolonial, beck, unpredictability, poland, slugging, labonte, luna,
# Nearest to was: is, has, became, were, had, been, be, being,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to he: she, it, they, there, who, we, this, then,
# Nearest to two: three, six, four, one, five, seven, eight, zero,
# Nearest to not: still, freely, strikes, never, generally, really, usually, now,
# Nearest to american: british, italian, australian, english, vara, international, german, hurting,
# Nearest to to: will, would, dispense, vented, jaco, dopant, must, tetrahedral,
# Nearest to at: near, during, in, keyboardist, jesuits, substituting, anechoic, on,
# Nearest to been: become, be, was, already, being, were, previously, never,
# Nearest to in: during, within, chromatids, on, at, of, with, throughout,
# Average loss at step 82000: 3.407013
# Average loss at step 84000: 3.409306
# Average loss at step 86000: 3.391421
# Average loss at step 88000: 3.348937
# Average loss at step 90000: 3.366629
# Nearest to s: whose, his, isbn, phillips, frontage, competitor, battled, rohrabacher,
# Nearest to they: we, he, there, she, you, it, but, these,
# Nearest to world: gulf, faroe, nation, esquire, csa, secretly, judgement, flagging,
# Nearest to many: several, some, various, these, all, most, numerous, few,
# Nearest to his: her, their, its, our, my, the, your, whose,
# Nearest to war: wars, precolonial, slugging, unpredictability, beck, luna, poland, glen,
# Nearest to was: is, became, had, has, were, be, been, being,
# Nearest to will: would, could, can, may, might, must, cannot, should,
# Nearest to he: she, it, they, there, who, but, later, then,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to not: still, strikes, freely, generally, nor, t, invited, really,
# Nearest to american: british, canadian, italian, german, european, english, elegans, korean,
# Nearest to to: will, towards, would, tick, tetrahedral, vented, wikiproject, desalination,
# Nearest to at: near, during, under, veteran, on, around, after, in,
# Nearest to been: become, be, already, being, was, subscription, previously, conner,
# Nearest to in: during, within, under, chromatids, on, at, periodicity, since,
# Average loss at step 92000: 3.400824
# Average loss at step 94000: 3.256049
# Average loss at step 96000: 3.356926
# Average loss at step 98000: 3.244824
# Average loss at step 100000: 3.353044
# Nearest to s: his, whose, frontage, cooperatives, shielded, injections, kev, imitative,
# Nearest to they: we, he, there, you, she, it, not, i,
# Nearest to world: afield, game, country, judgement, wounding, misspelling, faroe, gulf,
# Nearest to many: several, some, various, these, numerous, all, few, most,
# Nearest to his: her, their, our, my, its, your, the, s,
# Nearest to war: wars, precolonial, beck, poland, blockaded, glen, luna, merman,
# Nearest to was: is, became, has, were, had, being, been, transformers,
# Nearest to will: would, can, could, may, must, might, cannot, should,
# Nearest to he: she, it, they, there, we, who, subsequently, brevity,
# Nearest to two: five, three, four, six, seven, eight, one, zero,
# Nearest to not: strikes, never, freely, really, they, t, still, generally,
# Nearest to american: british, canadian, italian, english, french, mutton, australian, elegans,
# Nearest to to: will, would, could, must, may, can, towards, should,
# Nearest to at: near, during, under, on, in, with, after, curtain,
# Nearest to been: become, be, already, was, subscription, being, previously, exons,
# Nearest to in: within, during, on, from, throughout, under, lcc, through,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
